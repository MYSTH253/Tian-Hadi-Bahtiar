# %% [markdown]
# <a href="https://colab.research.google.com/github/MYSTH253/Tian-Hadi-Bahtiar/blob/main/P2_Tian_Hadi_Bahtiar_2C1240039.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Meminta input angka dari user
angka = int(input("Masukkan sebuah bilangan: "))

# Mengecek apakah habis dibagi 3
if angka % 3 == 0:
    print("Bilangan tersebut habis dibagi 3.")
else:
    print("Bilangan tersebut tidak habis dibagi 3.")
# Out:
# Masukkan sebuah bilangan: 9
# Bilangan tersebut habis dibagi 3.

# %%
# Meminta nama user
nama = input("Masukkan nama Anda: ")

# Meminta jenis kelamin
jenis_kelamin = input("Masukkan jenis kelamin Anda (pria/wanita): ")

# Menentukan sapaan berdasarkan jenis kelamin
if jenis_kelamin == "pria":
    print(f"Halo bro {nama}!")
elif jenis_kelamin  == "wanita":
    print(f"Halo sis {nama}!")
else:
    print("Jenis kelamin tidak dikenali.")
# Out:
# Masukkan nama Anda: Tian
# Masukkan jenis kelamin Anda (pria/wanita): pria
# Halo bro Tian!

# %%
nilai = int(input("Masukan nilai ujian Anda:"))

if nilai >= 85:
  print("Nilai Anda: A")
elif nilai>= 70:
  print("Nilai Anda: B")
elif nilai >60:
  print("Nilai Anda: C")
else:
  print("Nilai Anda: D")
# Out:
# Masukan nilai ujian Anda:10
# Nilai Anda: D

# %%
jumlah_barang = int(input("Masukkan jumlah barang yang dibeli: "))

total_belanja = 0

for i in range(jumlah_barang):
    print(f"Barang ke-{i+1}")
    harga_satuan = float(input("Masukkan harga satuan barang: "))
    jumlah_unit = int(input("Masukkan jumlah unit barang: "))
    total_harga = harga_satuan * jumlah_unit
    total_belanja += total_harga

print(f"Total belanja adalah: Rp{total_belanja:.2f}")
# Out:
# Masukkan jumlah barang yang dibeli: 2
# Barang ke-1
# Masukkan harga satuan barang: 20
# Masukkan jumlah unit barang: 2
# Barang ke-2
# Masukkan harga satuan barang: 30
# Masukkan jumlah unit barang: 2
# Total belanja adalah: Rp100.00

# %%
#Contoh penggunaan While Loop
#Catatan: Penentuan ruang lingkup di Python bisa menggunakan tab alih-alihmenggunakan tanda kurung
count = 0
while (count < 9):
  print("The count is: ", count)
count = count + 1
print("Good bye!")
# Out:
# Streaming output truncated to the last 5000 lines.
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# ...
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:  0
# The count is:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-6fee4f83996e> in <cell line: 0>()
#       3 count = 0
#       4 while (count < 9):
# ----> 5   print("The count is: ", count)
#       6 count = count + 1
#       7 print("Good bye!")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in write(self, string)
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
a = 3
# blok while akan dieksekusi
# selama a > 0
while a > 0:
  print("a =", a, "> 0")
  a = a - 1
  print(" a sekarang :", a)
# Out:
# a = 3 > 0
#  a sekarang : 2
# a = 2 > 0
#  a sekarang : 1
# a = 1 > 0
#  a sekarang : 0

# %%
# contoh INFINITE LOOP
# !!!hentikan program secara manual!!!
# nilai b = 1 dan 1 > 0
# karena nilai b tidak pernah berubah di dalam loop
# maka kondisi akan selalu bernilai True
b = 1 # b akan selalu bernilai 1
while b > 0:
  print("infinite loop")
# Out:
# Streaming output truncated to the last 5000 lines.
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# ...
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-38a32a225c76> in <cell line: 0>()
#       6 b = 1 # b akan selalu bernilai 1
#       7 while b > 0:
# ----> 8   print("infinite loop")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in write(self, string)
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
jawab = 'ya'
hitung = 0
while(jawab == 'ya'):
  hitung += 1
  jawab = input("Ulang lagi tidak? ")
print("Total perulagan: ",hitung)
# Out:
# Ulang lagi tidak? ya
# Ulang lagi tidak? tidak
# Total perulagan:  2

# %%
#Contoh pengulangan for sederhana
angka = [1,2,3,4,5]
for x in angka:
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Contoh pengulangan for
buah = ["nanas", "apel", "jeruk"]
for makanan in buah:
  print ("Saya suka makan", makanan)
# Out:
# Saya suka makan nanas
# Saya suka makan apel
# Saya suka makan jeruk

# %%
ulang = 10
for i in range(ulang):
print(f"Perulangan ke-{i}")

# %%
# mencetak "Pikachu" sebanyak 5x
for _ in range(5):
print("Pikachu")

# %%
# mencetak nilai kuadrat 1-10 dengan step=2
for val in range(1, 10, 2):
val_kuadrat = val**2
print(f"{val}^2 adalah {val_kuadrat}")

# %%
# iterasi pada list
skills = ["Python", "R", "Julia", "Scala"]
for skill in skills:
print("Anda menguasai", skill)
print("-------------------------")
# iterasi pada list dengan menyertakan indeks (key)
for idx, skill in enumerate(skills):
print(f"Skill ke-{idx+1} : {skill}")

# %%
# Program Python dengan Nested Loop
# Input jumlah baris
baris = int(input("Masukkan jumlah baris: "))
# Loop untuk membuat pola
for i in range(1, baris + 1):
for j in range(1, i + 1):
print("*", end=" ")
print() # Pindah ke baris berikutnya

# %%
#Menamai Pasangan Hewan
hewan1 = ["Kucing", "Kelinci", "Hamster"]
hewan2 = ["Besar", "Kecil"]
print("Pasangan hewan:")
for h1 in hewan1:
for h2 in hewan2:
print(h1, h2)

# %%
#Daftar Hari dan Waktu
hari = ["Senin", "Selasa", "Rabu"]
waktu = ["Pagi", "Siang", "Malam"]
print("Jadwal hari dan waktu:")
for h in hari:
for w in waktu:
print(h, w)

# %%
#Permainan Tebak Angka
angka_rahasia = [1, 3, 5]
angka_tebakan = [2, 3, 4, 5]
print("Hasil tebakan angka:")
for rahasia in angka_rahasia:
for tebakan in angka_tebakan:
if rahasia == tebakan:
print(f"Benar! Angka {tebakan} cocok.")
else:
print(f"Angka {tebakan} salah.")
# Out:
#   File "<ipython-input-23-18683f509eb7>", line 6
#     for tebakan in angka_tebakan:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 5

# %%
# ============ WHILE DENGAN ELSE ============ #
b = 1
while b < 5:
print("b masih lebih kecil dari 5")
b = b + 1
else:
print("b sekarang sama dengan 5")
# break : menghentikan iterasi total
print("\n-------BREAK-----------")
skill = ["Python", "R", "Julia", "Scala"] # data dalam bentuk list
print("start loop")
for val in skill:
# jika val = "Julia" hentikan iterasi
if val == "Julia":
break
print(" Bahasa", val)
print("end loop")
# continue ; menghentikan iterasi saat ini
# dan langsung melanjutkan iterasi berikutnya
print("\n------CONTINUE---------")
print("start loop")
a = 0
while a < 5:
a = a + 1
# jika nilai a 2 atau 3 : continue
if a == 2 or a == 3:
continue
print(" nilai a =", a)
print("end loop
